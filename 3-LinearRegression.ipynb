# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import seaborn as sns

# %%
cars_file = 'https://gist.githubusercontent.com/noamross/e5d3e859aa0c794be10b/raw/b999fb4425b54c63cab088c0ce2c0d6ce961a563/cars.csv'
cars = pd.read_csv(cars_file)
cars.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
sns.scatterplot(x='wt', y='mpg', data=cars)
sns.regplot(x='wt', y='mpg', data=cars)
# Out:
# <Axes: xlabel='wt', ylabel='mpg'>

# %% [markdown]
# #### Convert data to tensors

# %%
X_list = cars.wt.values
X_np = np.array(X_list, dtype=np.float32).reshape(-1,1)
y_list = cars.mpg.values.tolist()
y_np = np.array(y_list, dtype=np.float32).reshape(-1,1)
X = torch.from_numpy(X_np)
y = torch.tensor(y_list)

# %% [markdown]
# #### Training

# %%
w = torch.rand(1, requires_grad=True, dtype=torch.float64)
b = torch.rand(1, requires_grad=True, dtype=torch.float64)

num_epochs = 1000
learning_rate = 1e-3
for epoch in range(num_epochs):
  for i in range(len(X)):
    # forward pass
    y_predict = X[i] * w + b
    # calculate loss
    loss_tensor = torch.pow(y_predict - y[i], 2)
    # backward pass
    loss_tensor.backward()
    # extract losses
    loss_value = loss_tensor.data[0]
    # update weights and biases
    with torch.no_grad():
      w -= w.grad * learning_rate
      b -= b.grad * learning_rate
      w.grad.zero_()
      b.grad.zero_()
  print(loss_value)
# Out:
# tensor(159.2089, dtype=torch.float64)
# tensor(82.2563, dtype=torch.float64)
# tensor(55.4472, dtype=torch.float64)
# tensor(44.8029, dtype=torch.float64)
# tensor(40.1240, dtype=torch.float64)
# tensor(37.8628, dtype=torch.float64)
# tensor(36.6364, dtype=torch.float64)
# tensor(35.8664, dtype=torch.float64)
# tensor(35.3017, dtype=torch.float64)
# tensor(34.8312, dtype=torch.float64)
# tensor(34.4051, dtype=torch.float64)
# tensor(34.0013, dtype=torch.float64)
# tensor(33.6097, dtype=torch.float64)
# tensor(33.2258, dtype=torch.float64)
# tensor(32.8476, dtype=torch.float64)
# tensor(32.4741, dtype=torch.float64)
# tensor(32.1049, dtype=torch.float64)
# tensor(31.7397, dtype=torch.float64)
# tensor(31.3784, dtype=torch.float64)
# tensor(31.0210, dtype=torch.float64)
# tensor(30.6674, dtype=torch.float64)
# tensor(30.3176, dtype=torch.float64)
# tensor(29.9714, dtype=torch.float64)
# tensor(29.6289, dtype=torch.float64)
# tensor(29.2901, dtype=torch.float64)
# tensor(28.9548, dtype=torch.float64)
# tensor(28.6231, dtype=torch.float64)
# tensor(28.2949, dtype=torch.float64)
# tensor(27.9702, dtype=torch.float64)
# tensor(27.6490, dtype=torch.float64)
# tensor(27.3312, dtype=torch.float64)
# tensor(27.0167, dtype=torch.float64)
# tensor(26.7056, dtype=torch.float64)
# tensor(26.3978, dtype=torch.float64)
# tensor(26.0933, dtype=torch.float64)
# tensor(25.7920, dtype=torch.float64)
# tensor(25.4939, dtype=torch.float64)
# tensor(25.1990, dtype=torch.float64)
# tensor(24.9073, dtype=torch.float64)
# tensor(24.6186, dtype=torch.float64)
# tensor(24.3331, dtype=torch.float64)
# tensor(24.0506, dtype=torch.float64)
# tensor(23.7711, dtype=torch.float64)
# tensor(23.4946, dtype=torch.float64)
# tensor(23.2211, dtype=torch.float64)
# tensor(22.9505, dtype=torch.float64)
# tensor(22.6828, dtype=torch.float64)
# tensor(22.4179, dtype=torch.float64)
# tensor(22.1559, dtype=torch.float64)
# tensor(21.8967, dtype=torch.float64)
# tensor(21.6403, dtype=torch.float64)
# tensor(21.3867, dtype=torch.float64)
# tensor(21.1358, dtype=torch.float64)
# tensor(20.8875, dtype=torch.float64)
# tensor(20.6420, dtype=torch.float64)
# tensor(20.3991, dtype=torch.float64)
# tensor(20.1588, dtype=torch.float64)
# tensor(19.9211, dtype=torch.float64)
# tensor(19.6859, dtype=torch.float64)
# tensor(19.4533, dtype=torch.float64)
# tensor(19.2232, dtype=torch.float64)
# tensor(18.9956, dtype=torch.float64)
# tensor(18.7704, dtype=torch.float64)
# tensor(18.5477, dtype=torch.float64)
# tensor(18.3274, dtype=torch.float64)
# tensor(18.1095, dtype=torch.float64)
# tensor(17.8939, dtype=torch.float64)
# tensor(17.6807, dtype=torch.float64)
# tensor(17.4698, dtype=torch.float64)
# tensor(17.2611, dtype=torch.float64)
# tensor(17.0548, dtype=torch.float64)
# tensor(16.8506, dtype=torch.float64)
# tensor(16.6487, dtype=torch.float64)
# tensor(16.4490, dtype=torch.float64)
# tensor(16.2515, dtype=torch.float64)
# tensor(16.0561, dtype=torch.float64)
# tensor(15.8628, dtype=torch.float64)
# tensor(15.6717, dtype=torch.float64)
# tensor(15.4826, dtype=torch.float64)
# tensor(15.2956, dtype=torch.float64)
# tensor(15.1107, dtype=torch.float64)
# tensor(14.9277, dtype=torch.float64)
# tensor(14.7468, dtype=torch.float64)
# tensor(14.5679, dtype=torch.float64)
# tensor(14.3909, dtype=torch.float64)
# tensor(14.2158, dtype=torch.float64)
# tensor(14.0427, dtype=torch.float64)
# tensor(13.8715, dtype=torch.float64)
# tensor(13.7021, dtype=torch.float64)
# tensor(13.5346, dtype=torch.float64)
# tensor(13.3690, dtype=torch.float64)
# tensor(13.2051, dtype=torch.float64)
# tensor(13.0431, dtype=torch.float64)
# tensor(12.8829, dtype=torch.float64)
# tensor(12.7244, dtype=torch.float64)
# tensor(12.5677, dtype=torch.float64)
# tensor(12.4127, dtype=torch.float64)
# tensor(12.2594, dtype=torch.float64)
# tensor(12.1078, dtype=torch.float64)
# tensor(11.9579, dtype=torch.float64)
# tensor(11.8097, dtype=torch.float64)
# tensor(11.6631, dtype=torch.float64)
# tensor(11.5181, dtype=torch.float64)
# tensor(11.3748, dtype=torch.float64)
# tensor(11.2330, dtype=torch.float64)
# tensor(11.0928, dtype=torch.float64)
# tensor(10.9542, dtype=torch.float64)
# tensor(10.8171, dtype=torch.float64)
# tensor(10.6815, dtype=torch.float64)
# tensor(10.5475, dtype=torch.float64)
# tensor(10.4149, dtype=torch.float64)
# tensor(10.2838, dtype=torch.float64)
# tensor(10.1542, dtype=torch.float64)
# tensor(10.0261, dtype=torch.float64)
# tensor(9.8993, dtype=torch.float64)
# tensor(9.7740, dtype=torch.float64)
# tensor(9.6501, dtype=torch.float64)
# tensor(9.5276, dtype=torch.float64)
# tensor(9.4065, dtype=torch.float64)
# tensor(9.2867, dtype=torch.float64)
# tensor(9.1683, dtype=torch.float64)
# tensor(9.0512, dtype=torch.float64)
# tensor(8.9354, dtype=torch.float64)
# tensor(8.8210, dtype=torch.float64)
# tensor(8.7078, dtype=torch.float64)
# tensor(8.5959, dtype=torch.float64)
# tensor(8.4853, dtype=torch.float64)
# tensor(8.3759, dtype=torch.float64)
# tensor(8.2678, dtype=torch.float64)
# tensor(8.1609, dtype=torch.float64)
# tensor(8.0552, dtype=torch.float64)
# tensor(7.9507, dtype=torch.float64)
# tensor(7.8474, dtype=torch.float64)
# tensor(7.7453, dtype=torch.float64)
# tensor(7.6443, dtype=torch.float64)
# tensor(7.5445, dtype=torch.float64)
# tensor(7.4458, dtype=torch.float64)
# tensor(7.3483, dtype=torch.float64)
# tensor(7.2519, dtype=torch.float64)
# tensor(7.1565, dtype=torch.float64)
# tensor(7.0623, dtype=torch.float64)
# tensor(6.9692, dtype=torch.float64)
# tensor(6.8771, dtype=torch.float64)
# tensor(6.7860, dtype=torch.float64)
# tensor(6.6961, dtype=torch.float64)
# tensor(6.6071, dtype=torch.float64)
# tensor(6.5192, dtype=torch.float64)
# tensor(6.4323, dtype=torch.float64)
# tensor(6.3464, dtype=torch.float64)
# tensor(6.2615, dtype=torch.float64)
# tensor(6.1776, dtype=torch.float64)
# tensor(6.0947, dtype=torch.float64)
# tensor(6.0127, dtype=torch.float64)
# tensor(5.9316, dtype=torch.float64)
# tensor(5.8516, dtype=torch.float64)
# tensor(5.7724, dtype=torch.float64)
# tensor(5.6942, dtype=torch.float64)
# tensor(5.6168, dtype=torch.float64)
# tensor(5.5404, dtype=torch.float64)
# tensor(5.4649, dtype=torch.float64)
# tensor(5.3903, dtype=torch.float64)
# tensor(5.3165, dtype=torch.float64)
# tensor(5.2436, dtype=torch.float64)
# tensor(5.1715, dtype=torch.float64)
# tensor(5.1003, dtype=torch.float64)
# tensor(5.0300, dtype=torch.float64)
# tensor(4.9605, dtype=torch.float64)
# tensor(4.8917, dtype=torch.float64)
# tensor(4.8239, dtype=torch.float64)
# tensor(4.7568, dtype=torch.float64)
# tensor(4.6905, dtype=torch.float64)
# tensor(4.6249, dtype=torch.float64)
# tensor(4.5602, dtype=torch.float64)
# tensor(4.4962, dtype=torch.float64)
# tensor(4.4330, dtype=torch.float64)
# tensor(4.3706, dtype=torch.float64)
# tensor(4.3089, dtype=torch.float64)
# tensor(4.2479, dtype=torch.float64)
# tensor(4.1877, dtype=torch.float64)
# tensor(4.1282, dtype=torch.float64)
# tensor(4.0694, dtype=torch.float64)
# tensor(4.0113, dtype=torch.float64)
# tensor(3.9539, dtype=torch.float64)
# tensor(3.8972, dtype=torch.float64)
# tensor(3.8411, dtype=torch.float64)
# tensor(3.7858, dtype=torch.float64)
# tensor(3.7311, dtype=torch.float64)
# tensor(3.6771, dtype=torch.float64)
# tensor(3.6237, dtype=torch.float64)
# tensor(3.5710, dtype=torch.float64)
# tensor(3.5190, dtype=torch.float64)
# tensor(3.4675, dtype=torch.float64)
# tensor(3.4167, dtype=torch.float64)
# tensor(3.3665, dtype=torch.float64)
# tensor(3.3170, dtype=torch.float64)
# tensor(3.2680, dtype=torch.float64)
# tensor(3.2196, dtype=torch.float64)
# tensor(3.1719, dtype=torch.float64)
# tensor(3.1247, dtype=torch.float64)
# tensor(3.0781, dtype=torch.float64)
# tensor(3.0321, dtype=torch.float64)
# tensor(2.9866, dtype=torch.float64)
# tensor(2.9417, dtype=torch.float64)
# tensor(2.8974, dtype=torch.float64)
# tensor(2.8536, dtype=torch.float64)
# tensor(2.8104, dtype=torch.float64)
# tensor(2.7677, dtype=torch.float64)
# tensor(2.7255, dtype=torch.float64)
# tensor(2.6839, dtype=torch.float64)
# tensor(2.6428, dtype=torch.float64)
# tensor(2.6022, dtype=torch.float64)
# tensor(2.5621, dtype=torch.float64)
# tensor(2.5225, dtype=torch.float64)
# tensor(2.4834, dtype=torch.float64)
# tensor(2.4448, dtype=torch.float64)
# tensor(2.4067, dtype=torch.float64)
# tensor(2.3691, dtype=torch.float64)
# tensor(2.3320, dtype=torch.float64)
# tensor(2.2953, dtype=torch.float64)
# tensor(2.2591, dtype=torch.float64)
# tensor(2.2234, dtype=torch.float64)
# tensor(2.1881, dtype=torch.float64)
# tensor(2.1533, dtype=torch.float64)
# tensor(2.1189, dtype=torch.float64)
# tensor(2.0850, dtype=torch.float64)
# tensor(2.0515, dtype=torch.float64)
# tensor(2.0184, dtype=torch.float64)
# tensor(1.9858, dtype=torch.float64)
# tensor(1.9535, dtype=torch.float64)
# tensor(1.9218, dtype=torch.float64)
# tensor(1.8904, dtype=torch.float64)
# tensor(1.8594, dtype=torch.float64)
# tensor(1.8288, dtype=torch.float64)
# tensor(1.7987, dtype=torch.float64)
# tensor(1.7689, dtype=torch.float64)
# tensor(1.7395, dtype=torch.float64)
# tensor(1.7106, dtype=torch.float64)
# tensor(1.6820, dtype=torch.float64)
# tensor(1.6537, dtype=torch.float64)
# tensor(1.6259, dtype=torch.float64)
# tensor(1.5984, dtype=torch.float64)
# tensor(1.5713, dtype=torch.float64)
# tensor(1.5446, dtype=torch.float64)
# tensor(1.5182, dtype=torch.float64)
# tensor(1.4921, dtype=torch.float64)
# tensor(1.4665, dtype=torch.float64)
# tensor(1.4411, dtype=torch.float64)
# tensor(1.4161, dtype=torch.float64)
# tensor(1.3915, dtype=torch.float64)
# tensor(1.3672, dtype=torch.float64)
# tensor(1.3432, dtype=torch.float64)
# tensor(1.3195, dtype=torch.float64)
# tensor(1.2962, dtype=torch.float64)
# tensor(1.2732, dtype=torch.float64)
# tensor(1.2505, dtype=torch.float64)
# tensor(1.2281, dtype=torch.float64)
# tensor(1.2060, dtype=torch.float64)
# tensor(1.1843, dtype=torch.float64)
# tensor(1.1628, dtype=torch.float64)
# tensor(1.1416, dtype=torch.float64)
# tensor(1.1208, dtype=torch.float64)
# tensor(1.1002, dtype=torch.float64)
# tensor(1.0799, dtype=torch.float64)
# tensor(1.0599, dtype=torch.float64)
# tensor(1.0402, dtype=torch.float64)
# tensor(1.0208, dtype=torch.float64)
# tensor(1.0016, dtype=torch.float64)
# tensor(0.9827, dtype=torch.float64)
# tensor(0.9641, dtype=torch.float64)
# tensor(0.9458, dtype=torch.float64)
# tensor(0.9277, dtype=torch.float64)
# tensor(0.9099, dtype=torch.float64)
# tensor(0.8923, dtype=torch.float64)
# tensor(0.8750, dtype=torch.float64)
# tensor(0.8580, dtype=torch.float64)
# tensor(0.8412, dtype=torch.float64)
# tensor(0.8246, dtype=torch.float64)
# tensor(0.8083, dtype=torch.float64)
# tensor(0.7923, dtype=torch.float64)
# tensor(0.7764, dtype=torch.float64)
# tensor(0.7608, dtype=torch.float64)
# tensor(0.7455, dtype=torch.float64)
# tensor(0.7304, dtype=torch.float64)
# tensor(0.7155, dtype=torch.float64)
# tensor(0.7008, dtype=torch.float64)
# tensor(0.6863, dtype=torch.float64)
# tensor(0.6721, dtype=torch.float64)
# tensor(0.6581, dtype=torch.float64)
# tensor(0.6443, dtype=torch.float64)
# tensor(0.6307, dtype=torch.float64)
# tensor(0.6173, dtype=torch.float64)
# tensor(0.6042, dtype=torch.float64)
# tensor(0.5912, dtype=torch.float64)
# tensor(0.5784, dtype=torch.float64)
# tensor(0.5659, dtype=torch.float64)
# tensor(0.5535, dtype=torch.float64)
# tensor(0.5414, dtype=torch.float64)
# tensor(0.5294, dtype=torch.float64)
# tensor(0.5176, dtype=torch.float64)
# tensor(0.5060, dtype=torch.float64)
# tensor(0.4946, dtype=torch.float64)
# tensor(0.4834, dtype=torch.float64)
# tensor(0.4724, dtype=torch.float64)
# tensor(0.4615, dtype=torch.float64)
# tensor(0.4508, dtype=torch.float64)
# tensor(0.4403, dtype=torch.float64)
# tensor(0.4300, dtype=torch.float64)
# tensor(0.4198, dtype=torch.float64)
# tensor(0.4099, dtype=torch.float64)
# tensor(0.4000, dtype=torch.float64)
# tensor(0.3904, dtype=torch.float64)
# tensor(0.3809, dtype=torch.float64)
# tensor(0.3716, dtype=torch.float64)
# tensor(0.3624, dtype=torch.float64)
# tensor(0.3534, dtype=torch.float64)
# tensor(0.3446, dtype=torch.float64)
# tensor(0.3359, dtype=torch.float64)
# tensor(0.3273, dtype=torch.float64)
# tensor(0.3189, dtype=torch.float64)
# tensor(0.3107, dtype=torch.float64)
# tensor(0.3026, dtype=torch.float64)
# tensor(0.2946, dtype=torch.float64)
# tensor(0.2868, dtype=torch.float64)
# tensor(0.2792, dtype=torch.float64)
# tensor(0.2717, dtype=torch.float64)
# tensor(0.2643, dtype=torch.float64)
# tensor(0.2570, dtype=torch.float64)
# tensor(0.2499, dtype=torch.float64)
# tensor(0.2429, dtype=torch.float64)
# tensor(0.2361, dtype=torch.float64)
# tensor(0.2294, dtype=torch.float64)
# tensor(0.2228, dtype=torch.float64)
# tensor(0.2163, dtype=torch.float64)
# tensor(0.2100, dtype=torch.float64)
# tensor(0.2038, dtype=torch.float64)
# tensor(0.1977, dtype=torch.float64)
# tensor(0.1918, dtype=torch.float64)
# tensor(0.1859, dtype=torch.float64)
# tensor(0.1802, dtype=torch.float64)
# tensor(0.1746, dtype=torch.float64)
# tensor(0.1691, dtype=torch.float64)
# tensor(0.1637, dtype=torch.float64)
# tensor(0.1585, dtype=torch.float64)
# tensor(0.1533, dtype=torch.float64)
# tensor(0.1483, dtype=torch.float64)
# tensor(0.1433, dtype=torch.float64)
# tensor(0.1385, dtype=torch.float64)
# tensor(0.1338, dtype=torch.float64)
# tensor(0.1291, dtype=torch.float64)
# tensor(0.1246, dtype=torch.float64)
# tensor(0.1202, dtype=torch.float64)
# tensor(0.1159, dtype=torch.float64)
# tensor(0.1117, dtype=torch.float64)
# tensor(0.1076, dtype=torch.float64)
# tensor(0.1036, dtype=torch.float64)
# tensor(0.0996, dtype=torch.float64)
# tensor(0.0958, dtype=torch.float64)
# tensor(0.0921, dtype=torch.float64)
# tensor(0.0884, dtype=torch.float64)
# tensor(0.0849, dtype=torch.float64)
# tensor(0.0814, dtype=torch.float64)
# tensor(0.0780, dtype=torch.float64)
# tensor(0.0747, dtype=torch.float64)
# tensor(0.0715, dtype=torch.float64)
# tensor(0.0684, dtype=torch.float64)
# tensor(0.0654, dtype=torch.float64)
# tensor(0.0624, dtype=torch.float64)
# tensor(0.0596, dtype=torch.float64)
# tensor(0.0568, dtype=torch.float64)
# tensor(0.0541, dtype=torch.float64)
# tensor(0.0515, dtype=torch.float64)
# tensor(0.0489, dtype=torch.float64)
# tensor(0.0464, dtype=torch.float64)
# tensor(0.0440, dtype=torch.float64)
# tensor(0.0417, dtype=torch.float64)
# tensor(0.0395, dtype=torch.float64)
# tensor(0.0373, dtype=torch.float64)
# tensor(0.0352, dtype=torch.float64)
# tensor(0.0332, dtype=torch.float64)
# tensor(0.0312, dtype=torch.float64)
# tensor(0.0293, dtype=torch.float64)
# tensor(0.0275, dtype=torch.float64)
# tensor(0.0257, dtype=torch.float64)
# tensor(0.0240, dtype=torch.float64)
# tensor(0.0224, dtype=torch.float64)
# tensor(0.0208, dtype=torch.float64)
# tensor(0.0193, dtype=torch.float64)
# tensor(0.0179, dtype=torch.float64)
# tensor(0.0165, dtype=torch.float64)
# tensor(0.0152, dtype=torch.float64)
# tensor(0.0140, dtype=torch.float64)
# tensor(0.0128, dtype=torch.float64)
# tensor(0.0116, dtype=torch.float64)
# tensor(0.0106, dtype=torch.float64)
# tensor(0.0095, dtype=torch.float64)
# tensor(0.0086, dtype=torch.float64)
# tensor(0.0077, dtype=torch.float64)
# tensor(0.0068, dtype=torch.float64)
# tensor(0.0060, dtype=torch.float64)
# tensor(0.0053, dtype=torch.float64)
# tensor(0.0046, dtype=torch.float64)
# tensor(0.0039, dtype=torch.float64)
# tensor(0.0034, dtype=torch.float64)
# tensor(0.0028, dtype=torch.float64)
# tensor(0.0023, dtype=torch.float64)
# tensor(0.0019, dtype=torch.float64)
# tensor(0.0015, dtype=torch.float64)
# tensor(0.0011, dtype=torch.float64)
# tensor(0.0008, dtype=torch.float64)
# tensor(0.0006, dtype=torch.float64)
# tensor(0.0004, dtype=torch.float64)
# tensor(0.0002, dtype=torch.float64)
# tensor(0.0001, dtype=torch.float64)
# tensor(3.2420e-05, dtype=torch.float64)
# tensor(1.1783e-06, dtype=torch.float64)
# tensor(1.2252e-05, dtype=torch.float64)
# tensor(6.5023e-05, dtype=torch.float64)
# tensor(0.0002, dtype=torch.float64)
# tensor(0.0003, dtype=torch.float64)
# tensor(0.0005, dtype=torch.float64)
# tensor(0.0007, dtype=torch.float64)
# tensor(0.0009, dtype=torch.float64)
# tensor(0.0012, dtype=torch.float64)
# tensor(0.0016, dtype=torch.float64)
# tensor(0.0019, dtype=torch.float64)
# tensor(0.0023, dtype=torch.float64)
# tensor(0.0028, dtype=torch.float64)
# tensor(0.0032, dtype=torch.float64)
# tensor(0.0037, dtype=torch.float64)
# tensor(0.0043, dtype=torch.float64)
# tensor(0.0049, dtype=torch.float64)
# tensor(0.0055, dtype=torch.float64)
# tensor(0.0061, dtype=torch.float64)
# tensor(0.0068, dtype=torch.float64)
# tensor(0.0075, dtype=torch.float64)
# tensor(0.0082, dtype=torch.float64)
# tensor(0.0090, dtype=torch.float64)
# tensor(0.0098, dtype=torch.float64)
# tensor(0.0106, dtype=torch.float64)
# tensor(0.0115, dtype=torch.float64)
# tensor(0.0124, dtype=torch.float64)
# tensor(0.0133, dtype=torch.float64)
# tensor(0.0142, dtype=torch.float64)
# tensor(0.0152, dtype=torch.float64)
# tensor(0.0162, dtype=torch.float64)
# tensor(0.0172, dtype=torch.float64)
# tensor(0.0182, dtype=torch.float64)
# tensor(0.0193, dtype=torch.float64)
# tensor(0.0204, dtype=torch.float64)
# tensor(0.0215, dtype=torch.float64)
# tensor(0.0227, dtype=torch.float64)
# tensor(0.0239, dtype=torch.float64)
# tensor(0.0251, dtype=torch.float64)
# tensor(0.0263, dtype=torch.float64)
# tensor(0.0275, dtype=torch.float64)
# tensor(0.0288, dtype=torch.float64)
# tensor(0.0301, dtype=torch.float64)
# tensor(0.0314, dtype=torch.float64)
# tensor(0.0327, dtype=torch.float64)
# tensor(0.0341, dtype=torch.float64)
# tensor(0.0354, dtype=torch.float64)
# tensor(0.0368, dtype=torch.float64)
# tensor(0.0382, dtype=torch.float64)
# tensor(0.0397, dtype=torch.float64)
# tensor(0.0411, dtype=torch.float64)
# tensor(0.0426, dtype=torch.float64)
# tensor(0.0441, dtype=torch.float64)
# tensor(0.0456, dtype=torch.float64)
# tensor(0.0471, dtype=torch.float64)
# tensor(0.0486, dtype=torch.float64)
# tensor(0.0502, dtype=torch.float64)
# tensor(0.0518, dtype=torch.float64)
# tensor(0.0533, dtype=torch.float64)
# tensor(0.0550, dtype=torch.float64)
# tensor(0.0566, dtype=torch.float64)
# tensor(0.0582, dtype=torch.float64)
# tensor(0.0599, dtype=torch.float64)
# tensor(0.0615, dtype=torch.float64)
# tensor(0.0632, dtype=torch.float64)
# tensor(0.0649, dtype=torch.float64)
# tensor(0.0666, dtype=torch.float64)
# tensor(0.0683, dtype=torch.float64)
# tensor(0.0701, dtype=torch.float64)
# tensor(0.0718, dtype=torch.float64)
# tensor(0.0736, dtype=torch.float64)
# tensor(0.0754, dtype=torch.float64)
# tensor(0.0772, dtype=torch.float64)
# tensor(0.0790, dtype=torch.float64)
# tensor(0.0808, dtype=torch.float64)
# tensor(0.0826, dtype=torch.float64)
# tensor(0.0844, dtype=torch.float64)
# tensor(0.0863, dtype=torch.float64)
# tensor(0.0881, dtype=torch.float64)
# tensor(0.0900, dtype=torch.float64)
# tensor(0.0919, dtype=torch.float64)
# tensor(0.0938, dtype=torch.float64)
# tensor(0.0957, dtype=torch.float64)
# tensor(0.0976, dtype=torch.float64)
# tensor(0.0995, dtype=torch.float64)
# tensor(0.1014, dtype=torch.float64)
# tensor(0.1033, dtype=torch.float64)
# tensor(0.1053, dtype=torch.float64)
# tensor(0.1072, dtype=torch.float64)
# tensor(0.1092, dtype=torch.float64)
# tensor(0.1112, dtype=torch.float64)
# tensor(0.1131, dtype=torch.float64)
# tensor(0.1151, dtype=torch.float64)
# tensor(0.1171, dtype=torch.float64)
# tensor(0.1191, dtype=torch.float64)
# tensor(0.1211, dtype=torch.float64)
# tensor(0.1231, dtype=torch.float64)
# tensor(0.1251, dtype=torch.float64)
# tensor(0.1272, dtype=torch.float64)
# tensor(0.1292, dtype=torch.float64)
# tensor(0.1312, dtype=torch.float64)
# tensor(0.1333, dtype=torch.float64)
# tensor(0.1353, dtype=torch.float64)
# tensor(0.1374, dtype=torch.float64)
# tensor(0.1394, dtype=torch.float64)
# tensor(0.1415, dtype=torch.float64)
# tensor(0.1436, dtype=torch.float64)
# tensor(0.1456, dtype=torch.float64)
# tensor(0.1477, dtype=torch.float64)
# tensor(0.1498, dtype=torch.float64)
# tensor(0.1519, dtype=torch.float64)
# tensor(0.1540, dtype=torch.float64)
# tensor(0.1561, dtype=torch.float64)
# tensor(0.1582, dtype=torch.float64)
# tensor(0.1603, dtype=torch.float64)
# tensor(0.1624, dtype=torch.float64)
# tensor(0.1645, dtype=torch.float64)
# tensor(0.1666, dtype=torch.float64)
# tensor(0.1687, dtype=torch.float64)
# tensor(0.1708, dtype=torch.float64)
# tensor(0.1730, dtype=torch.float64)
# tensor(0.1751, dtype=torch.float64)
# tensor(0.1772, dtype=torch.float64)
# tensor(0.1793, dtype=torch.float64)
# tensor(0.1815, dtype=torch.float64)
# tensor(0.1836, dtype=torch.float64)
# tensor(0.1857, dtype=torch.float64)
# tensor(0.1879, dtype=torch.float64)
# tensor(0.1900, dtype=torch.float64)
# tensor(0.1921, dtype=torch.float64)
# tensor(0.1943, dtype=torch.float64)
# tensor(0.1964, dtype=torch.float64)
# tensor(0.1986, dtype=torch.float64)
# tensor(0.2007, dtype=torch.float64)
# tensor(0.2029, dtype=torch.float64)
# tensor(0.2050, dtype=torch.float64)
# tensor(0.2072, dtype=torch.float64)
# tensor(0.2093, dtype=torch.float64)
# tensor(0.2115, dtype=torch.float64)
# tensor(0.2136, dtype=torch.float64)
# tensor(0.2157, dtype=torch.float64)
# tensor(0.2179, dtype=torch.float64)
# tensor(0.2200, dtype=torch.float64)
# tensor(0.2222, dtype=torch.float64)
# tensor(0.2243, dtype=torch.float64)
# tensor(0.2265, dtype=torch.float64)
# tensor(0.2286, dtype=torch.float64)
# tensor(0.2308, dtype=torch.float64)
# tensor(0.2329, dtype=torch.float64)
# tensor(0.2351, dtype=torch.float64)
# tensor(0.2372, dtype=torch.float64)
# tensor(0.2394, dtype=torch.float64)
# tensor(0.2415, dtype=torch.float64)
# tensor(0.2437, dtype=torch.float64)
# tensor(0.2458, dtype=torch.float64)
# tensor(0.2479, dtype=torch.float64)
# tensor(0.2501, dtype=torch.float64)
# tensor(0.2522, dtype=torch.float64)
# tensor(0.2544, dtype=torch.float64)
# tensor(0.2565, dtype=torch.float64)
# tensor(0.2586, dtype=torch.float64)
# tensor(0.2608, dtype=torch.float64)
# tensor(0.2629, dtype=torch.float64)
# tensor(0.2650, dtype=torch.float64)
# tensor(0.2671, dtype=torch.float64)
# tensor(0.2693, dtype=torch.float64)
# tensor(0.2714, dtype=torch.float64)
# tensor(0.2735, dtype=torch.float64)
# tensor(0.2756, dtype=torch.float64)
# tensor(0.2778, dtype=torch.float64)
# tensor(0.2799, dtype=torch.float64)
# tensor(0.2820, dtype=torch.float64)
# tensor(0.2841, dtype=torch.float64)
# tensor(0.2862, dtype=torch.float64)
# tensor(0.2883, dtype=torch.float64)
# tensor(0.2904, dtype=torch.float64)
# tensor(0.2925, dtype=torch.float64)
# tensor(0.2946, dtype=torch.float64)
# tensor(0.2967, dtype=torch.float64)
# tensor(0.2988, dtype=torch.float64)
# tensor(0.3009, dtype=torch.float64)
# tensor(0.3029, dtype=torch.float64)
# tensor(0.3050, dtype=torch.float64)
# tensor(0.3071, dtype=torch.float64)
# tensor(0.3092, dtype=torch.float64)
# tensor(0.3113, dtype=torch.float64)
# tensor(0.3133, dtype=torch.float64)
# tensor(0.3154, dtype=torch.float64)
# tensor(0.3174, dtype=torch.float64)
# tensor(0.3195, dtype=torch.float64)
# tensor(0.3216, dtype=torch.float64)
# tensor(0.3236, dtype=torch.float64)
# tensor(0.3257, dtype=torch.float64)
# tensor(0.3277, dtype=torch.float64)
# tensor(0.3297, dtype=torch.float64)
# tensor(0.3318, dtype=torch.float64)
# tensor(0.3338, dtype=torch.float64)
# tensor(0.3358, dtype=torch.float64)
# tensor(0.3379, dtype=torch.float64)
# tensor(0.3399, dtype=torch.float64)
# tensor(0.3419, dtype=torch.float64)
# tensor(0.3439, dtype=torch.float64)
# tensor(0.3459, dtype=torch.float64)
# tensor(0.3479, dtype=torch.float64)
# tensor(0.3499, dtype=torch.float64)
# tensor(0.3519, dtype=torch.float64)
# tensor(0.3539, dtype=torch.float64)
# tensor(0.3559, dtype=torch.float64)
# tensor(0.3579, dtype=torch.float64)
# tensor(0.3599, dtype=torch.float64)
# tensor(0.3619, dtype=torch.float64)
# tensor(0.3638, dtype=torch.float64)
# tensor(0.3658, dtype=torch.float64)
# tensor(0.3678, dtype=torch.float64)
# tensor(0.3697, dtype=torch.float64)
# tensor(0.3717, dtype=torch.float64)
# tensor(0.3736, dtype=torch.float64)
# tensor(0.3756, dtype=torch.float64)
# tensor(0.3775, dtype=torch.float64)
# tensor(0.3794, dtype=torch.float64)
# tensor(0.3814, dtype=torch.float64)
# tensor(0.3833, dtype=torch.float64)
# tensor(0.3852, dtype=torch.float64)
# tensor(0.3872, dtype=torch.float64)
# tensor(0.3891, dtype=torch.float64)
# tensor(0.3910, dtype=torch.float64)
# tensor(0.3929, dtype=torch.float64)
# tensor(0.3948, dtype=torch.float64)
# tensor(0.3967, dtype=torch.float64)
# tensor(0.3986, dtype=torch.float64)
# tensor(0.4004, dtype=torch.float64)
# tensor(0.4023, dtype=torch.float64)
# tensor(0.4042, dtype=torch.float64)
# tensor(0.4061, dtype=torch.float64)
# tensor(0.4079, dtype=torch.float64)
# tensor(0.4098, dtype=torch.float64)
# tensor(0.4117, dtype=torch.float64)
# tensor(0.4135, dtype=torch.float64)
# tensor(0.4154, dtype=torch.float64)
# tensor(0.4172, dtype=torch.float64)
# tensor(0.4190, dtype=torch.float64)
# tensor(0.4209, dtype=torch.float64)
# tensor(0.4227, dtype=torch.float64)
# tensor(0.4245, dtype=torch.float64)
# tensor(0.4263, dtype=torch.float64)
# tensor(0.4281, dtype=torch.float64)
# tensor(0.4299, dtype=torch.float64)
# tensor(0.4317, dtype=torch.float64)
# tensor(0.4335, dtype=torch.float64)
# tensor(0.4353, dtype=torch.float64)
# tensor(0.4371, dtype=torch.float64)
# tensor(0.4389, dtype=torch.float64)
# tensor(0.4407, dtype=torch.float64)
# tensor(0.4424, dtype=torch.float64)
# tensor(0.4442, dtype=torch.float64)
# tensor(0.4460, dtype=torch.float64)
# tensor(0.4477, dtype=torch.float64)
# tensor(0.4495, dtype=torch.float64)
# tensor(0.4512, dtype=torch.float64)
# tensor(0.4530, dtype=torch.float64)
# tensor(0.4547, dtype=torch.float64)
# tensor(0.4564, dtype=torch.float64)
# tensor(0.4581, dtype=torch.float64)
# tensor(0.4599, dtype=torch.float64)
# tensor(0.4616, dtype=torch.float64)
# tensor(0.4633, dtype=torch.float64)
# tensor(0.4650, dtype=torch.float64)
# tensor(0.4667, dtype=torch.float64)
# tensor(0.4684, dtype=torch.float64)
# tensor(0.4701, dtype=torch.float64)
# tensor(0.4718, dtype=torch.float64)
# tensor(0.4734, dtype=torch.float64)
# tensor(0.4751, dtype=torch.float64)
# tensor(0.4768, dtype=torch.float64)
# tensor(0.4784, dtype=torch.float64)
# tensor(0.4801, dtype=torch.float64)
# tensor(0.4817, dtype=torch.float64)
# tensor(0.4834, dtype=torch.float64)
# tensor(0.4850, dtype=torch.float64)
# tensor(0.4867, dtype=torch.float64)
# tensor(0.4883, dtype=torch.float64)
# tensor(0.4899, dtype=torch.float64)
# tensor(0.4915, dtype=torch.float64)
# tensor(0.4931, dtype=torch.float64)
# tensor(0.4947, dtype=torch.float64)
# tensor(0.4964, dtype=torch.float64)
# tensor(0.4979, dtype=torch.float64)
# tensor(0.4995, dtype=torch.float64)
# tensor(0.5011, dtype=torch.float64)
# tensor(0.5027, dtype=torch.float64)
# tensor(0.5043, dtype=torch.float64)
# tensor(0.5059, dtype=torch.float64)
# tensor(0.5074, dtype=torch.float64)
# tensor(0.5090, dtype=torch.float64)
# tensor(0.5105, dtype=torch.float64)
# tensor(0.5121, dtype=torch.float64)
# tensor(0.5136, dtype=torch.float64)
# tensor(0.5152, dtype=torch.float64)
# tensor(0.5167, dtype=torch.float64)
# tensor(0.5182, dtype=torch.float64)
# tensor(0.5198, dtype=torch.float64)
# tensor(0.5213, dtype=torch.float64)
# tensor(0.5228, dtype=torch.float64)
# tensor(0.5243, dtype=torch.float64)
# tensor(0.5258, dtype=torch.float64)
# tensor(0.5273, dtype=torch.float64)
# tensor(0.5288, dtype=torch.float64)
# tensor(0.5303, dtype=torch.float64)
# tensor(0.5318, dtype=torch.float64)
# tensor(0.5333, dtype=torch.float64)
# tensor(0.5347, dtype=torch.float64)
# tensor(0.5362, dtype=torch.float64)
# tensor(0.5377, dtype=torch.float64)
# tensor(0.5391, dtype=torch.float64)
# tensor(0.5406, dtype=torch.float64)
# tensor(0.5420, dtype=torch.float64)
# tensor(0.5434, dtype=torch.float64)
# tensor(0.5449, dtype=torch.float64)
# tensor(0.5463, dtype=torch.float64)
# tensor(0.5477, dtype=torch.float64)
# tensor(0.5492, dtype=torch.float64)
# tensor(0.5506, dtype=torch.float64)
# tensor(0.5520, dtype=torch.float64)
# tensor(0.5534, dtype=torch.float64)
# tensor(0.5548, dtype=torch.float64)
# tensor(0.5562, dtype=torch.float64)
# tensor(0.5576, dtype=torch.float64)
# tensor(0.5590, dtype=torch.float64)
# tensor(0.5603, dtype=torch.float64)
# tensor(0.5617, dtype=torch.float64)
# tensor(0.5631, dtype=torch.float64)
# tensor(0.5644, dtype=torch.float64)
# tensor(0.5658, dtype=torch.float64)
# tensor(0.5672, dtype=torch.float64)
# tensor(0.5685, dtype=torch.float64)
# tensor(0.5699, dtype=torch.float64)
# tensor(0.5712, dtype=torch.float64)
# tensor(0.5725, dtype=torch.float64)
# tensor(0.5739, dtype=torch.float64)
# tensor(0.5752, dtype=torch.float64)
# tensor(0.5765, dtype=torch.float64)
# tensor(0.5778, dtype=torch.float64)
# tensor(0.5791, dtype=torch.float64)
# tensor(0.5804, dtype=torch.float64)
# tensor(0.5817, dtype=torch.float64)
# tensor(0.5830, dtype=torch.float64)
# tensor(0.5843, dtype=torch.float64)
# tensor(0.5856, dtype=torch.float64)
# tensor(0.5869, dtype=torch.float64)
# tensor(0.5882, dtype=torch.float64)
# tensor(0.5894, dtype=torch.float64)
# tensor(0.5907, dtype=torch.float64)
# tensor(0.5920, dtype=torch.float64)
# tensor(0.5932, dtype=torch.float64)
# tensor(0.5945, dtype=torch.float64)
# tensor(0.5957, dtype=torch.float64)
# tensor(0.5970, dtype=torch.float64)
# tensor(0.5982, dtype=torch.float64)
# tensor(0.5994, dtype=torch.float64)
# tensor(0.6006, dtype=torch.float64)
# tensor(0.6019, dtype=torch.float64)
# tensor(0.6031, dtype=torch.float64)
# tensor(0.6043, dtype=torch.float64)
# tensor(0.6055, dtype=torch.float64)
# tensor(0.6067, dtype=torch.float64)
# tensor(0.6079, dtype=torch.float64)
# tensor(0.6091, dtype=torch.float64)
# tensor(0.6103, dtype=torch.float64)
# tensor(0.6115, dtype=torch.float64)
# tensor(0.6127, dtype=torch.float64)
# tensor(0.6138, dtype=torch.float64)
# tensor(0.6150, dtype=torch.float64)
# tensor(0.6162, dtype=torch.float64)
# tensor(0.6173, dtype=torch.float64)
# tensor(0.6185, dtype=torch.float64)
# tensor(0.6196, dtype=torch.float64)
# tensor(0.6208, dtype=torch.float64)
# tensor(0.6219, dtype=torch.float64)
# tensor(0.6231, dtype=torch.float64)
# tensor(0.6242, dtype=torch.float64)
# tensor(0.6253, dtype=torch.float64)
# tensor(0.6265, dtype=torch.float64)
# tensor(0.6276, dtype=torch.float64)
# tensor(0.6287, dtype=torch.float64)
# tensor(0.6298, dtype=torch.float64)
# tensor(0.6309, dtype=torch.float64)
# tensor(0.6320, dtype=torch.float64)
# tensor(0.6331, dtype=torch.float64)
# tensor(0.6342, dtype=torch.float64)
# tensor(0.6353, dtype=torch.float64)
# tensor(0.6364, dtype=torch.float64)
# tensor(0.6375, dtype=torch.float64)
# tensor(0.6385, dtype=torch.float64)
# tensor(0.6396, dtype=torch.float64)
# tensor(0.6407, dtype=torch.float64)
# tensor(0.6417, dtype=torch.float64)
# tensor(0.6428, dtype=torch.float64)
# tensor(0.6439, dtype=torch.float64)
# tensor(0.6449, dtype=torch.float64)
# tensor(0.6460, dtype=torch.float64)
# tensor(0.6470, dtype=torch.float64)
# tensor(0.6480, dtype=torch.float64)
# tensor(0.6491, dtype=torch.float64)
# tensor(0.6501, dtype=torch.float64)
# tensor(0.6511, dtype=torch.float64)
# tensor(0.6521, dtype=torch.float64)
# tensor(0.6532, dtype=torch.float64)
# tensor(0.6542, dtype=torch.float64)
# tensor(0.6552, dtype=torch.float64)
# tensor(0.6562, dtype=torch.float64)
# tensor(0.6572, dtype=torch.float64)
# tensor(0.6582, dtype=torch.float64)
# tensor(0.6592, dtype=torch.float64)
# tensor(0.6602, dtype=torch.float64)
# tensor(0.6611, dtype=torch.float64)
# tensor(0.6621, dtype=torch.float64)
# tensor(0.6631, dtype=torch.float64)
# tensor(0.6641, dtype=torch.float64)
# tensor(0.6650, dtype=torch.float64)
# tensor(0.6660, dtype=torch.float64)
# tensor(0.6669, dtype=torch.float64)
# tensor(0.6679, dtype=torch.float64)
# tensor(0.6689, dtype=torch.float64)
# tensor(0.6698, dtype=torch.float64)
# tensor(0.6707, dtype=torch.float64)
# tensor(0.6717, dtype=torch.float64)
# tensor(0.6726, dtype=torch.float64)
# tensor(0.6735, dtype=torch.float64)
# tensor(0.6745, dtype=torch.float64)
# tensor(0.6754, dtype=torch.float64)
# tensor(0.6763, dtype=torch.float64)
# tensor(0.6772, dtype=torch.float64)
# tensor(0.6781, dtype=torch.float64)
# tensor(0.6791, dtype=torch.float64)
# tensor(0.6800, dtype=torch.float64)
# tensor(0.6809, dtype=torch.float64)
# tensor(0.6818, dtype=torch.float64)
# tensor(0.6826, dtype=torch.float64)
# tensor(0.6835, dtype=torch.float64)
# tensor(0.6844, dtype=torch.float64)
# tensor(0.6853, dtype=torch.float64)
# tensor(0.6862, dtype=torch.float64)
# tensor(0.6871, dtype=torch.float64)
# tensor(0.6879, dtype=torch.float64)
# tensor(0.6888, dtype=torch.float64)
# tensor(0.6896, dtype=torch.float64)
# tensor(0.6905, dtype=torch.float64)
# tensor(0.6914, dtype=torch.float64)
# tensor(0.6922, dtype=torch.float64)
# tensor(0.6931, dtype=torch.float64)
# tensor(0.6939, dtype=torch.float64)
# tensor(0.6947, dtype=torch.float64)
# tensor(0.6956, dtype=torch.float64)
# tensor(0.6964, dtype=torch.float64)
# tensor(0.6972, dtype=torch.float64)
# tensor(0.6981, dtype=torch.float64)
# tensor(0.6989, dtype=torch.float64)
# tensor(0.6997, dtype=torch.float64)
# tensor(0.7005, dtype=torch.float64)
# tensor(0.7013, dtype=torch.float64)
# tensor(0.7022, dtype=torch.float64)
# tensor(0.7030, dtype=torch.float64)
# tensor(0.7038, dtype=torch.float64)
# tensor(0.7046, dtype=torch.float64)
# tensor(0.7054, dtype=torch.float64)
# tensor(0.7061, dtype=torch.float64)
# tensor(0.7069, dtype=torch.float64)
# tensor(0.7077, dtype=torch.float64)
# tensor(0.7085, dtype=torch.float64)
# tensor(0.7093, dtype=torch.float64)
# tensor(0.7100, dtype=torch.float64)
# tensor(0.7108, dtype=torch.float64)
# tensor(0.7116, dtype=torch.float64)
# tensor(0.7124, dtype=torch.float64)
# tensor(0.7131, dtype=torch.float64)
# tensor(0.7139, dtype=torch.float64)
# tensor(0.7146, dtype=torch.float64)
# tensor(0.7154, dtype=torch.float64)
# tensor(0.7161, dtype=torch.float64)
# tensor(0.7169, dtype=torch.float64)
# tensor(0.7176, dtype=torch.float64)
# tensor(0.7183, dtype=torch.float64)
# tensor(0.7191, dtype=torch.float64)
# tensor(0.7198, dtype=torch.float64)
# tensor(0.7205, dtype=torch.float64)
# tensor(0.7213, dtype=torch.float64)
# tensor(0.7220, dtype=torch.float64)
# tensor(0.7227, dtype=torch.float64)
# tensor(0.7234, dtype=torch.float64)
# tensor(0.7241, dtype=torch.float64)
# tensor(0.7248, dtype=torch.float64)
# tensor(0.7255, dtype=torch.float64)
# tensor(0.7263, dtype=torch.float64)
# tensor(0.7269, dtype=torch.float64)
# tensor(0.7276, dtype=torch.float64)
# tensor(0.7283, dtype=torch.float64)
# tensor(0.7290, dtype=torch.float64)
# tensor(0.7297, dtype=torch.float64)
# tensor(0.7304, dtype=torch.float64)
# tensor(0.7311, dtype=torch.float64)
# tensor(0.7318, dtype=torch.float64)
# tensor(0.7324, dtype=torch.float64)
# tensor(0.7331, dtype=torch.float64)
# tensor(0.7338, dtype=torch.float64)
# tensor(0.7344, dtype=torch.float64)
# tensor(0.7351, dtype=torch.float64)
# tensor(0.7358, dtype=torch.float64)
# tensor(0.7364, dtype=torch.float64)
# tensor(0.7371, dtype=torch.float64)
# tensor(0.7377, dtype=torch.float64)
# tensor(0.7384, dtype=torch.float64)
# tensor(0.7390, dtype=torch.float64)
# tensor(0.7397, dtype=torch.float64)
# tensor(0.7403, dtype=torch.float64)
# tensor(0.7410, dtype=torch.float64)
# tensor(0.7416, dtype=torch.float64)
# tensor(0.7422, dtype=torch.float64)
# tensor(0.7428, dtype=torch.float64)
# tensor(0.7435, dtype=torch.float64)
# tensor(0.7441, dtype=torch.float64)
# tensor(0.7447, dtype=torch.float64)
# tensor(0.7453, dtype=torch.float64)
# tensor(0.7459, dtype=torch.float64)
# tensor(0.7466, dtype=torch.float64)
# tensor(0.7472, dtype=torch.float64)
# tensor(0.7478, dtype=torch.float64)
# tensor(0.7484, dtype=torch.float64)
# tensor(0.7490, dtype=torch.float64)
# tensor(0.7496, dtype=torch.float64)
# tensor(0.7502, dtype=torch.float64)
# tensor(0.7508, dtype=torch.float64)
# tensor(0.7514, dtype=torch.float64)
# tensor(0.7519, dtype=torch.float64)
# tensor(0.7525, dtype=torch.float64)
# tensor(0.7531, dtype=torch.float64)
# tensor(0.7537, dtype=torch.float64)
# tensor(0.7543, dtype=torch.float64)
# tensor(0.7548, dtype=torch.float64)
# tensor(0.7554, dtype=torch.float64)
# tensor(0.7560, dtype=torch.float64)
# tensor(0.7566, dtype=torch.float64)
# tensor(0.7571, dtype=torch.float64)
# tensor(0.7577, dtype=torch.float64)
# tensor(0.7582, dtype=torch.float64)
# tensor(0.7588, dtype=torch.float64)
# tensor(0.7594, dtype=torch.float64)
# tensor(0.7599, dtype=torch.float64)
# tensor(0.7605, dtype=torch.float64)
# tensor(0.7610, dtype=torch.float64)
# tensor(0.7615, dtype=torch.float64)
# tensor(0.7621, dtype=torch.float64)
# tensor(0.7626, dtype=torch.float64)
# tensor(0.7632, dtype=torch.float64)
# tensor(0.7637, dtype=torch.float64)
# tensor(0.7642, dtype=torch.float64)
# tensor(0.7648, dtype=torch.float64)
# tensor(0.7653, dtype=torch.float64)
# tensor(0.7658, dtype=torch.float64)
# tensor(0.7663, dtype=torch.float64)
# tensor(0.7669, dtype=torch.float64)
# tensor(0.7674, dtype=torch.float64)
# tensor(0.7679, dtype=torch.float64)
# tensor(0.7684, dtype=torch.float64)
# tensor(0.7689, dtype=torch.float64)
# tensor(0.7694, dtype=torch.float64)
# tensor(0.7699, dtype=torch.float64)
# tensor(0.7704, dtype=torch.float64)
# tensor(0.7709, dtype=torch.float64)
# tensor(0.7714, dtype=torch.float64)
# tensor(0.7719, dtype=torch.float64)
# tensor(0.7724, dtype=torch.float64)
# tensor(0.7729, dtype=torch.float64)
# tensor(0.7734, dtype=torch.float64)
# tensor(0.7739, dtype=torch.float64)
# tensor(0.7744, dtype=torch.float64)
# tensor(0.7749, dtype=torch.float64)
# tensor(0.7753, dtype=torch.float64)
# tensor(0.7758, dtype=torch.float64)
# tensor(0.7763, dtype=torch.float64)
# tensor(0.7768, dtype=torch.float64)
# tensor(0.7772, dtype=torch.float64)
# tensor(0.7777, dtype=torch.float64)
# tensor(0.7782, dtype=torch.float64)
# tensor(0.7786, dtype=torch.float64)
# tensor(0.7791, dtype=torch.float64)
# tensor(0.7796, dtype=torch.float64)

# %% [markdown]
# #### Check Results

# %%
print(f"Weight: {w.item()}, Bias: {b.item()}")
# Out:
# Weight: -5.229224165238386, Bias: 36.804761599422754

# %%
y_pred = (torch.tensor(X_list)*w+b).detach().numpy()

# %%
sns.scatterplot(x=X_list, y=y_list)
sns.lineplot(x=X_list, y=y_pred, color='red')
# Out:
# <Axes: >

# %% [markdown]
# #### (Statistical) Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_np, y_list)
print(f"Slope: {reg.coef_}, Bias: {reg.intercept_}")
# Out:
# Slope: [-5.3444715], Bias: 37.285125732421875
